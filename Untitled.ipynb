# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv('training.1600000.processed.noemoticon.csv', encoding='ISO-8859-1', header=None)

# %%
df.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
df.columns=['target', 'id','dates', 'Querry','user','text']

# %%
# # df_subset=df_subset.drop('id', axis=1)
# df_subset=df_subset.drop('dates', axis=1)
# df_subset=df_subset.drop('Querry', axis=1)
# df_subset=df_subset.drop('user', axis=1)
# df_subset

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Data processing

# %%
def processig_text(tweet):
    tweet = re.sub(r"http\S+|@\S+|#\S+", "", tweet)
    tweet = re.sub('[^a-zA-Z]', " ", tweet)
    tweet = tweet.lower()
    tokens = word_tokenize(tweet)
    
    return " ".join(tokens)

df['clean_text']= df['text'].apply(processig_text)

# %%
df
# Out:
#          target          id                         dates    Querry  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# ...

# %%
df['target'] = df['target'].replace({4:1, 2:1})

# %%
df
# Out:
#          target          id                         dates    Querry  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       1  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       1  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       1  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       1  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       1  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# ...

# %% [markdown]
# ## Training the model

# %%
##independent and dependent variable
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

## pickle model 
pickle.dump(vectorizer, open('vectorizer.pkl','wb'))

X = df['clean_text']
y = df['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# print(y_train.value_counts())

# %%
model.fit(X_train_vec,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_vec)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 0, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,  classification_report
accuracy_score = accuracy_score(y_pred, y_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79    263321
#            1       0.79      0.81      0.80    264679
#
#     accuracy                           0.80    528000
#    macro avg       0.80      0.80      0.80    528000
# weighted avg       0.80      0.80      0.80    528000

# %%
accuracy_score
# Out:
# 0.797340909090909

# %%
 classification_report(y_red, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 classification_report(y_red, y_test)
#
# NameError: name 'y_red' is not defined

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive/Neutral'], yticklabels=['Negative', 'Positive/Neutral'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Sentiment Analysis (Binary)')
plt.show()

# %% [markdown]
# ## New Data

# %%
x = df['clean_text'][1599998]

# %%
vectorizer.transform([x])
# Out:
# <1x205223 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>

# %%
model.predict(vectorizer.transform([x]))
# Out:
# array([1], dtype=int64)

# %% [raw]
# ##pickel model file development

# %%
import pickle

# %%
pickle.dump(model, open('regression.pkl', 'wb'))

# %%
pickle_model = pickle.load(open('regression.pkl', 'rb'))

# %%
pickle_model.predict(vectorizer.transform([x]))
# Out:
# array([1], dtype=int64)
